# %%
##LAB 4.04 Data cleaning and wrangling
# https://github.com/mazim-co/lab-data-cleaning-and-wrangling

# %%
ls
# Out:
# Untitled.ipynb                   lab-data-cleaning-and-wrangling/

# %%
import pandas as pd
import numpy as np
import datetime
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('/Users/mzimmermann/ironhack/week4/lessons_files/we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
#Header cleaning
#new_cols = [col.replace(" ", "_").lower() for col in data]
#data.columns = new_cols

# %%
cat_df = data.select_dtypes(np.object)
num_df = data.select_dtypes(np.number)

# %%
num_df.head(1)
# Out:
#    Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0              2763.519279   56274                    69
#
#    Months Since Last Claim  Months Since Policy Inception  \
# 0                       32                              5
#
#    Number of Open Complaints  Number of Policies  Total Claim Amount
# 0                          0                   1          384.811147

# %%
#iqr = np.percentile(data['IC1'],75) - np.percentile(data['IC1'],25)
#upper_limit = np.percentile(data['IC1'],75) + 1.5*iqr
#lower_limit = np.percentile(data['IC1'],25) - 1.5*iqr

# %%
#data = data[(data['IC1']>lower_limit) & (data['IC1']<upper_limit)]

# %%
sns.violinplot(data=num_df['Total Claim Amount'])
plt.show()

# %%
#ploting distirbution for numerical features
for val in num_df:
    plt.figure(figsize = (14,6))
    sns.distplot(num_df[val])
plt.show()

# %%
iqr = np.percentile(data['hv1'],75) - np.percentile(data['hv1'],25)
upper_limit = np.percentile(data['hv1'],75) + 1.5*iqr
lower_limit = np.percentile(data['hv1'],25) - 1.5*iqr
data = data[(data['hv1']>lower_limit) & (data['hv1']<upper_limit)]

# %%
sns.distplot(data['hv1'])
plt.show()
